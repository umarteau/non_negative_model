# %%
import numpy as np
import torch 
import pickle
import os
import matplotlib.pyplot as plt
import npm_nnf.utils.utils_kernels as KT 
import npm_nnf.density_estimation.utils_density as utils
import npm_nnf.density_estimation.utils_data as data

# %%
data_set_path = 'data_sets'

# %% [markdown]
# # Data set for first experiment in dimension d = 1

# %%
data_set_filename = 'experiment_1d.pickle'

# %%
n = 80
params = {
    'd' : 1,
    'mu' : 1.,
    'sigma' : 0.3,
    'n_mixture' : 2
}

# %%
#saving data set in the path
#ds = data.createDataSet(n=n,**params)
#pickle.dump(ds,open(os.path.join(data_set_path,data_set_filename),'wb'))

# %%
ds = pickle.load(open(os.path.join(data_set_path,data_set_filename),'rb'))

# %% [markdown]
# # Data set for second experiment in dimension d = 10

# %%
data_set_filename = 'experiment_10d.pickle'

# %%
n = 1000
params = {
    'd' : 10,
    'mu' : 2.,
    'sigma' : 1/np.sqrt(2*np.pi),
    'n_mixture' : 2
}

# %%
#saving data set in the path
#ds = data.createDataSet(n=n,**params)
#pickle.dump(ds,open(os.path.join(data_set_path,data_set_filename),'wb'))

# %%
ds = pickle.load(open(os.path.join(data_set_path,data_set_filename),'rb'))

# %%
plt.scatter(ds.X[:,0],ds.y)

# %%
ntest =100
Xtest = torch.zeros((ntest,10))
Xtest[:,0] = torch.linspace(-3,3,100)

plt.plot(Xtest[:,0],ds.apply_density(Xtest))
plt.show()

# %% [markdown]
# # Data set for second experiment in dimension d = 10

# %%
data_set_filename = 'experiment_10d_2.pickle'

# %%
n = 1000
params = {
    'd' : 10,
    'mu' : [2.,-2.],
    'sigma' : [1/np.sqrt(2*np.pi),0.25196867],
    'p' : [0.99,0.01],
    'n_mixture' : 2
}

# %%
#saving data set in the path
ds = data.createDataSet(n=n,**params)
pickle.dump(ds,open(os.path.join(data_set_path,data_set_filename),'wb'))
# Out:
# /sequoia/data1/umarteau/miniconda/envs/nips19/lib/python3.7/site-packages/torch/storage.py:34: FutureWarning: pickle support for Storage will be removed in 1.5. Use `torch.save` instead
#   warnings.warn("pickle support for Storage will be removed in 1.5. Use `torch.save` instead", FutureWarning)

# %%
ds = pickle.load(open(os.path.join(data_set_path,data_set_filename),'rb'))

# %%
plt.scatter(ds.X[:,0],ds.y)

# %%
ntest =100
Xtest = torch.zeros((ntest,10))
Xtest[:,0] = torch.linspace(-3,3,100)

plt.plot(Xtest[:,0],ds.apply_density(Xtest))
plt.show()
